# %%
import pandas as pd

# %%
df = pd.read_csv('year_quarter_combined_w_target_encoded.csv')

# %%
df
# Out:
#        RegionID   Home_Index  SizeRank  30_Yr_Mort_Rate        GDP  \
# 0        394913  178805.7511         1         8.102308   8032.840
# 1        394913  180891.4381         1         8.146923   8131.408
# 2        394913  181090.9894         1         7.703077   8259.771
# 3        394913  180635.7721         1         7.793077   8362.655
# 4        394913  182068.9644         1         7.926923   8518.825
# ...         ...          ...       ...              ...        ...
# 84435    102001  338317.7382         0         6.372308  26813.601
# 84436    102001  348777.2949         0         6.510769  27063.012
# 84437    102001  356315.4753         0         7.040000  27610.128
# 84438    102001  353596.3073         0         7.303846  27956.998
# 84439    102001  352295.2503         0         6.748462  28255.928
#
#               CPI  Unemp_Rate       Per_Inc   Population  Year_Quarter  \
# 0      156.533333    5.500000   6638.633333  269251.3333       1996.25
# ...

# %%
df.corr()
# Out:
#                            RegionID  Home_Index  SizeRank  30_Yr_Mort_Rate  \
# RegionID                   1.000000    0.126734  0.130815         0.000500
# Home_Index                 0.126734    1.000000 -0.219655        -0.113897
# SizeRank                   0.130815   -0.219655  1.000000        -0.107819
# 30_Yr_Mort_Rate            0.000500   -0.113897 -0.107819         1.000000
# GDP                        0.000651    0.390312  0.114755        -0.495740
# CPI                        0.000433    0.380988  0.121007        -0.523521
# Unemp_Rate                -0.002438   -0.130381  0.024365        -0.339754
# Per_Inc                    0.000597    0.387077  0.113938        -0.532191
# Population                 0.000287    0.335923  0.132201        -0.711181
# Year_Quarter               0.000395    0.356906  0.127135        -0.657783
# RegionName_Target_Encoded  0.157410    0.805125 -0.272820         0.015252
# ...

# %%
train_data = pd.read_csv('train_data.csv')
len(train_data)
# Out:
# 44174

# %%
val_data = pd.read_csv('val_data.csv')
len(val_data)
# Out:
# 20576

# %%
test_data = pd.read_csv('test_data.csv')
len(test_data)
# Out:
# 19690

# %%
columns = ['Home_Index', 'RegionName_Target_Encoded' ,'StateName_Target_Encoded', 'SizeRank', 'Year_Quarter', '30_Yr_Mort_Rate', 'GDP', 'CPI', 'Unemp_Rate', 'Per_Inc', 'Population']
corr_matrix = df[columns].corr()

# %%
corr_matrix
# Out:
#                            Home_Index  RegionName_Target_Encoded  \
# Home_Index                   1.000000                   0.805125
# RegionName_Target_Encoded    0.805125                   1.000000
# StateName_Target_Encoded     0.594992                   0.739006
# SizeRank                    -0.219655                  -0.272820
# Year_Quarter                 0.356906                  -0.017982
# 30_Yr_Mort_Rate             -0.113897                   0.015252
# GDP                          0.390312                  -0.016166
# CPI                          0.380988                  -0.017126
# Unemp_Rate                  -0.130381                  -0.004271
# Per_Inc                      0.387077                  -0.016104
# Population                   0.335923                  -0.018693
#
#                            StateName_Target_Encoded  SizeRank  Year_Quarter  \
# Home_Index                                 0.594992 -0.219655      0.356906
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Plot the correlation heatmap before handling zeros
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Reorder columns for each set
train_data = train_data[columns]
val_data = val_data[columns]
test_data = test_data[columns]


# Function to plot correlation heatmap
def plot_correlation_matrix(data, title):
    plt.figure(figsize=(12, 8))
    corr_matrix = data.corr()
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
    plt.title(title)
    plt.show()

# Plot correlation heatmaps for each subset
plot_correlation_matrix(train_data, 'Correlation Matrix - Training Set')
plot_correlation_matrix(val_data, 'Correlation Matrix - Validation Set')
plot_correlation_matrix(test_data, 'Correlation Matrix - Test Set')

# %%
from sklearn.preprocessing import StandardScaler

# %%
df = pd.DataFrame(df)

# %%
df
# Out:
#        RegionID   Home_Index  SizeRank  30_Yr_Mort_Rate        GDP  \
# 0        394913  178805.7511         1         8.102308   8032.840
# 1        394913  180891.4381         1         8.146923   8131.408
# 2        394913  181090.9894         1         7.703077   8259.771
# 3        394913  180635.7721         1         7.793077   8362.655
# 4        394913  182068.9644         1         7.926923   8518.825
# ...         ...          ...       ...              ...        ...
# 84435    102001  338317.7382         0         6.372308  26813.601
# 84436    102001  348777.2949         0         6.510769  27063.012
# 84437    102001  356315.4753         0         7.040000  27610.128
# 84438    102001  353596.3073         0         7.303846  27956.998
# 84439    102001  352295.2503         0         6.748462  28255.928
#
#               CPI  Unemp_Rate       Per_Inc   Population  Year_Quarter  \
# 0      156.533333    5.500000   6638.633333  269251.3333       1996.25
# ...

# %%
columns_to_standardize = ['SizeRank', 'GDP', 'CPI', 'Unemp_Rate', 'Per_Inc', 'Population']

# %%
scaler = StandardScaler()

# %%
# Assuming df is your training set for demonstration
train_data = df.copy()  
val_data = df.copy()  
test_data = df.copy()  

# Standardize the features in the training set
train_data[columns_to_standardize] = scaler.fit_transform(train_data[columns_to_standardize])

# Standardize the features in the validation and test sets
val_data[columns_to_standardize] = scaler.transform(val_data[columns_to_standardize])
test_data[columns_to_standardize] = scaler.transform(test_data[columns_to_standardize])

# %%
print(train_data[columns_to_standardize].mean(axis=0))  # Should be close to 0
print(train_data[columns_to_standardize].std(axis=0))   # Should be close to 1
# Out:
# SizeRank      6.462539e-17
# GDP          -8.832137e-16
# CPI           4.523778e-16
# Unemp_Rate    7.926708e-17
# Per_Inc      -6.947230e-16
# Population    2.663105e-15
# dtype: float64
# SizeRank      1.000006
# GDP           1.000006
# CPI           1.000006
# Unemp_Rate    1.000006
# Per_Inc       1.000006
# Population    1.000006
# dtype: float64

# %%
print(train_data[columns_to_standardize].mean(axis=0))
# Out:
# SizeRank      6.462539e-17
# GDP          -8.832137e-16
# CPI           4.523778e-16
# Unemp_Rate    7.926708e-17
# Per_Inc      -6.947230e-16
# Population    2.663105e-15
# dtype: float64
